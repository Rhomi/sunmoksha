# %%
import numpy as np
import pandas as pd

# %%
xls = pd.ExcelFile(r'C:\Users\Deepak George\Documents\GitHub\sunmoksha\data\Energy Data.xlsx')

# %%
bsn = pd.read_excel(xls, 'BSN', header=None)

# %%
enc = pd.read_excel(xls, 'ENC', header=None)

# %%
nes = pd.read_excel(xls, 'NES', header=None)

# %%
bsf = pd.read_excel(xls, 'BSF', header=None)

# %%
cpr = pd.read_excel(xls, 'CPR', header=None)

# %%
bsn
# Out:
#                             0                  1            2   \
# 0    BSN - College of Business                NaN          NaN
# 1                Chilled Water                NaN          NaN
# 2                        Meter  Total Consumption        Meter
# 3                         C218        66245700000         C251
# 4                         2007         6090600000         2007
# 5                            1          361800000            1
# 6                            2          275000000            2
# 7                            3          403200000            3
# 8                            4          390700000            4
# 9                            5          554000000            5
# 10                           6          443200000            6
# 11                           7          811500000            7
# 12                           8          649200000            8
# 13                           9          644300000            9
# ...
